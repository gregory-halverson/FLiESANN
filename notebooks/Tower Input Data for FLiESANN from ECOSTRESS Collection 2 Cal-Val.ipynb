# %%
import sys
import os
sys.path.insert(0, os.path.abspath(os.path.join(os.getcwd(), '..')))

# %%
import os
import numpy as np
import pandas as pd
import geopandas as gpd
from ECOv002_calval_tables import load_calval_table
from FLiESANN import load_ECOv002_calval_FLiESANN_inputs
from FLiESANN import load_ECOv002_static_tower_FLiESANN_inputs
from FLiESANN import process_FLiESANN_table

# %%
repo_root = os.path.dirname(os.getcwd())
package_dir = os.path.join(repo_root, 'FLiESANN')
generated_input_table_filename = os.path.join(package_dir, "ECOv002-cal-val-FLiESANN-inputs.csv")
generated_output_table_filename = os.path.join(package_dir, "ECOv002-cal-val-FLiESANN-outputs.csv")

# %%
# model_inputs_gdf = load_calval_table()
# model_inputs_gdf["elevation_km"] = model_inputs_gdf["Elev"] / 1000.0
model_inputs_gdf = load_ECOv002_calval_FLiESANN_inputs()
model_inputs_gdf.head()
# Out:
#    Unnamed: 0.1  Unnamed: 0      ID vegetation climate   STICinst   BESSinst  \
# 0             0           0  US-NC3        ENF     Cfa  270.34520   78.53355
# 1             1           1  US-Mi3        CVM     Dfb  232.14160  229.20093
# 2             2           2  US-Mi3        CVM     Dfb  356.35574  335.23154
# 3             3           3  US-Mi3        CVM     Dfb  332.93840  326.68680
# 4             4           4  US-Mi3        CVM     Dfb  286.85403  237.21654
#
#    MOD16inst  PTJPLSMinst      ETinst  ...  NIR_diffuse_Wm2  PAR_direct_Wm2  \
# 0  392.85184    307.02197  487.383423  ...     [38.2445125]  [198.62618615]
# 1  640.11847    375.08930  106.825577  ...             [0.]  [413.58122051]
# 2  625.66170    284.68625         NaN  ...     [9.68769447]  [384.74115359]
# 3  624.25433    251.41449  178.827545  ...     [1.93050927]  [384.15439992]
# 4  511.08218    228.52017  154.791626  ...    [14.65627117]  [322.41786441]
#
#    NIR_direct_Wm2  atmospheric_transmittance  UV_proportion  PAR_proportion  \
# 0  [263.38140473]                   0.718657       0.058531        0.467483
# 1  [504.05746725]                   0.844565       0.061096        0.442631
# 2  [468.46381158]                   0.814815       0.060993        0.453412
# 3  [463.02837748]                   0.822354       0.060754        0.445641
# 4  [383.68264643]                   0.782475       0.060677        0.452102
#
#    NIR_proportion  UV_diffuse_fraction  PAR_diffuse_fraction  \
# 0        0.474610             0.638061              0.331442
# 1        0.497649             0.337287              0.077509
# 2        0.486971             0.390321              0.135801
# 3        0.495001             0.339288              0.082276
# 4        0.488428             0.390727              0.125559
#
#    NIR_diffuse_fraction
# 0              0.126795
# 1              0.000000
# 2              0.020261
# 3              0.004152
# 4              0.036793
#
# [5 rows x 103 columns]

# %%
# static_inputs_df = load_ECOv002_static_tower_FLiESANN_inputs()
# static_inputs_df

# %%
# # merge static inputs with model inputs, ignoring duplicate columns from static_inputs_df
# cols_to_use = [col for col in static_inputs_df.columns if col not in model_inputs_gdf.columns or col == 'ID']
# model_inputs_gdf = model_inputs_gdf.merge(static_inputs_df[cols_to_use], on="ID", how="left")
# model_inputs_gdf

# %%
sorted(list(model_inputs_gdf.columns))
# Out:
# ['AirTempC',
#  'BESSinst',
#  'Clim',
#  'Date-Time',
#  'ESI',
#  'ESIrn_BESS',
#  'ESIrn_LEcorr50',
#  'ESIrn_MOD16',
#  'ESIrn_PTJPLSM',
#  'ESIrn_STIC',
#  'ESIrn_Unc_ECO',
#  'ETinst',
#  'ETinstUncertainty',
#  'Elev',
#  'EmisWB',
#  'EndDate',
#  'G_filt',
#  'H_filt',
#  'Hcorr25',
#  'Hcorr50',
#  'Hcorr75',
#  'Hcorr_ann',
#  'ID',
#  'JET',
#  'LE',
#  'LE_count',
#  'LE_filt',
#  'LEcorr25',
#  'LEcorr50',
#  'LEcorr75',
#  'LEcorr_ann',
#  'LST',
#  'LST_err',
#  'Lat',
#  'Long',
#  'MAP',
#  'MAT',
#  'MOD16inst',
#  'NDVI',
#  'NDVI-UQ',
#  'NETRAD_filt',
#  'NIR_Wm2',
#  'NIR_diffuse_Wm2',
#  'NIR_diffuse_fraction',
#  'NIR_direct_Wm2',
#  'NIR_proportion',
#  'Name',
#  'PAR_Wm2',
#  'PAR_diffuse_Wm2',
#  'PAR_diffuse_fraction',
#  'PAR_direct_Wm2',
#  'PAR_proportion',
#  'PET',
#  'PTJPLSMinst',
#  'RH',
#  'RH_percentage',
#  'Rg',
#  'Rn',
#  'SM',
#  'SM_rz',
#  'SM_surf',
#  'STICinst',
#  'ST_C',
#  'ST_K',
#  'SW_IN',
#  'SWin_TOA_Wm2',
#  'SWin_Wm2',
#  'Site ID',
#  'Site Name',
#  'StartDate',
#  'Ta',
#  'Ta_C',
#  'UV_Wm2',
#  'UV_diffuse_fraction',
#  'UV_proportion',
#  'Unnamed: 0',
#  'Unnamed: 0.1',
#  'Veg',
#  'albedo',
#  'albedo-UQ',
#  'atmospheric_transmittance',
#  'climate',
#  'closure_ratio',
#  'date_UTC',
#  'eco_time_utc',
#  'elevation_m',
#  'emissivity',
#  'geometry',
#  'insitu_ET_daylight_kg',
#  'insitu_G_Wm2',
#  'insitu_H_Wm2',
#  'insitu_LE_Wm2',
#  'insitu_LE_daylight_Wm2',
#  'insitu_Rn_Wm2',
#  'insitu_Rn_daylight_Wm2',
#  'insitu_SWin_Wm2',
#  'local_time',
#  'solar_hour',
#  'solar_time',
#  'time_UTC',
#  'time_utc',
#  'vegetation',
#  'view_zenith']

# %%
results = process_FLiESANN_table(model_inputs_gdf)
results
# Out:
# [2025-10-28 15:22:38 INFO] started processing FLiES input table
# [2025-10-28 15:22:38 INFO] processing table in vectorized mode
# [2025-10-28 15:22:38 INFO] processing 1065 rows in vectorized mode
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 results = process_FLiESANN_table(model_inputs_gdf)
#       2 results
#
# File ~/Projects/FLiESANN/FLiESANN/process_FLiESANN_table.py:153, in process_FLiESANN_table(input_df, GEOS5FP_connection, NASADEM_connection, row_wise)
#     150         return None
#     152 # Process all rows at once using vectorized FLiESANN call
# --> 153 FLiES_results = FLiESANN(
#     154     geometry=geometries,
#     155     time_UTC=times_UTC,
#     156     albedo=input_df.albedo.values,
#     157     COT=get_column_or_none(input_df, "COT"),
#     158     AOT=get_column_or_none(input_df, "AOT"),
#     159     vapor_gccm=get_column_or_none(input_df, "vapor_gccm"),
#     160     ozone_cm=get_column_or_none(input_df, "ozone_cm"),
#     161     elevation_m=get_column_or_none(input_df, "elevation_m"),
#     162     SZA=get_column_or_none(input_df, "SZA"),
#     163     KG_climate=get_column_or_none(input_df, "KG_climate", "KG"),
#     164     GEOS5FP_connection=GEOS5FP_connection,
#     165     NASADEM_connection=NASADEM_connection
#     166 )
#     168 # Add results to the output DataFrame
#     169 for key, values in FLiES_results.items():
#
# File ~/Projects/FLiESANN/FLiESANN/process_FLiESANN.py:183, in FLiESANN(albedo, COT, AOT, vapor_gccm, ozone_cm, elevation_m, SZA, KG_climate, SWin_Wm2, geometry, time_UTC, day_of_year, hour_of_day, GEOS5FP_connection, NASADEM_connection, resampling, ANN_model, model_filename, split_atypes_ctypes, zero_COT_correction)
#     176     COT = GEOS5FP_connection.COT(
#     177         time_UTC=time_UTC,
#     178         geometry=geometry,
#     179         resampling=resampling
#     180     )
#     182 if AOT is None and geometry is not None and time_UTC is not None:
# --> 183     AOT = GEOS5FP_connection.AOT(
#     184         time_UTC=time_UTC,
#     185         geometry=geometry,
#     186         resampling=resampling
#     187     )
#     189 if vapor_gccm is None and geometry is not None and time_UTC is not None:
#     190     vapor_gccm = GEOS5FP_connection.vapor_gccm(
#     191         time_UTC=time_UTC,
#     192         geometry=geometry,
#     193         resampling=resampling
#     194     )
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/FLiESANN/lib/python3.11/site-packages/GEOS5FP/GEOS5FP_connection.py:774, in GEOS5FPConnection.AOT(self, time_UTC, geometry, resampling)
#     768 # 1:30, 4:30, 7:30, 10:30, 13:30, 16:30, 19:30, 22:30 UTC
#     769 EXPECTED_HOURS = [1.5, 4.5, 7.5, 10.5, 13.5, 16.5, 19.5, 22.5]
#     771 logger.info(
#     772     f"retrieving {cl.name(NAME)} "
#     773     f"from GEOS-5 FP {cl.name(PRODUCT)} {cl.name(VARIABLE)} " +
# --> 774     "for " + cl.time(f"{time_UTC:%Y-%m-%d %H:%M} UTC")
#     775 )
#     777 return self.interpolate(
#     778     time_UTC=time_UTC,
#     779     product=PRODUCT,
#    (...)    783     expected_hours=EXPECTED_HOURS
#     784 )
#
# TypeError: unsupported format string passed to Series.__format__

# %%
model_inputs_gdf.to_csv(generated_input_table_filename, index=False)

# %%
results.to_csv(generated_output_table_filename, index=False)
