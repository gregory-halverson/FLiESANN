# %%
import pandas as pd

# %%
with_insitu = pd.read_csv("../FLiESANN/ECOv002-cal-val-FLiESANN-inputs.csv")
with_insitu
# Out:
#       Unnamed: 0      ID vegetation climate    STICinst   BESSinst  \
# 0              0  US-NC3        ENF     Cfa  270.345200   78.53355
# 1              1  US-Mi3        CVM     Dfb  232.141600  229.20093
# 2              2  US-Mi3        CVM     Dfb  356.355740  335.23154
# 3              3  US-Mi3        CVM     Dfb  332.938400  326.68680
# 4              4  US-Mi3        CVM     Dfb  286.854030  237.21654
# ...          ...     ...        ...     ...         ...        ...
# 1060        1060  US-xAE        GRA     Cfa   70.923310  172.37459
# 1061        1061  US-xAE        GRA     Cfa  116.543190  121.81641
# 1062        1062  US-xAE        GRA     Cfa  129.880100    0.00000
# 1063        1063  US-xAE        GRA     Cfa    2.707851  140.38632
# 1064        1064  US-xAE        GRA     Cfa  303.242950    0.00000
#
#        MOD16inst  PTJPLSMinst      ETinst  ETinstUncertainty  ...  \
# 0     392.851840   307.021970  487.383423         118.916280  ...
# ...

# %%
with_meteorology = pd.read_csv("../FLiESANN/ECOv002-cal-val-FliESANN-inputs-complete.csv")
with_meteorology
# Out:
#       Unnamed: 0.1  Unnamed: 0      ID vegetation climate    STICinst  \
# 0                0           0  US-NC3        ENF     Cfa  270.345200
# 1                1           1  US-Mi3        CVM     Dfb  232.141600
# 2                2           2  US-Mi3        CVM     Dfb  356.355740
# 3                3           3  US-Mi3        CVM     Dfb  332.938400
# 4                4           4  US-Mi3        CVM     Dfb  286.854030
# ...            ...         ...     ...        ...     ...         ...
# 1060          1060        1060  US-xAE        GRA     Cfa   70.923310
# 1061          1061        1061  US-xAE        GRA     Cfa  116.543190
# 1062          1062        1062  US-xAE        GRA     Cfa  129.880100
# 1063          1063        1063  US-xAE        GRA     Cfa    2.707851
# 1064          1064        1064  US-xAE        GRA     Cfa  303.242950
#
#        BESSinst   MOD16inst  PTJPLSMinst      ETinst  ...  NIR_diffuse_Wm2  \
# ...
